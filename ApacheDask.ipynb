# %%
import dask.dataframe as dd
import pandas as pd
import json, ast
from haversine import haversine, Unit

# %% [markdown]
# For each restaurant (‘Restaurants_in_Durham_County_NC.csv) with “status”=“ACTIVE” and “"rpt_area_desc"="Food Service", show the number of foreclosures (‘durham-nc-foreclosure-2006-2016’) within a radius of 1 mile of the restaurant’s coordinates.

# %%
def format_data(file):
    with open(file, 'r') as f:
        data = json.load(f)
    return pd.json_normalize(data)

restaurants = dd.from_pandas(format_data('shared/hw2/Restaurants_in_Durham_County_NC.json'))
foreclosure = dd.from_pandas(format_data('shared/hw2/durham-nc-foreclosure-2006-2016.json'))
print(restaurants.head(10))
print(foreclosure.head(10))
# Out:
#           datasetid                                  recordid  \
# 0  restaurants-data  1644654b953d1802c3c941211f61be1f727b2951
# 1  restaurants-data  93573dbf8c9e799d82c459e47de0f40a2faa47bb
# 2  restaurants-data  0d274200c7cef50d05dd633bc5da896a69e1bb99
# 3  restaurants-data  cf3e0b175a6ebad2a9aa8edb4b3985c6391ed31d
# 4  restaurants-data  e796570677f7c39cc90d4870f192a9beb928560a
# 5  restaurants-data  90cdb7722ea7d4ffde931d1b9c45fec2ad97378e
# 6  restaurants-data  a777677a2690466efa03b77e411566eecd76d26f
# 7  restaurants-data  f8e7a2243f9edb2cd5d08c13add936bd43eca09c
# 8  restaurants-data  b13c50f485bd92b042fd065523c58e5480531f9b
# 9  restaurants-data  f71fd314be631c0fe1226cf4485385d992ea45b6
#
#             record_timestamp fields.status         fields.geolocation  \
# 0  2017-07-13T09:15:31-04:00        ACTIVE  [35.9207272, -78.9573299]
# 1  2017-07-13T09:15:31-04:00        ACTIVE  [36.0467802, -78.8895483]
# 2  2017-07-13T09:15:31-04:00        ACTIVE  [35.9182655, -78.9593263]
# 3  2017-07-13T09:15:31-04:00        ACTIVE  [36.0183378, -78.9060312]
# 4  2017-07-13T09:15:31-04:00        ACTIVE  [36.0556347, -78.9135175]
# 5  2017-07-13T09:15:31-04:00        ACTIVE   [35.984012, -78.8077969]
# 6  2017-07-13T09:15:31-04:00        ACTIVE  [35.9857413, -78.8865863]
# 7  2017-07-13T09:15:31-04:00        ACTIVE   [35.913596, -78.9602128]
# 8  2017-07-13T09:15:31-04:00        ACTIVE   [36.0111429, -78.953045]
# 9  2017-07-13T09:15:31-04:00        ACTIVE   [36.0184133, -78.947422]
#
#   fields.premise_zip fields.rpt_area_desc  fields.risk  \
# 0              27707         Food Service            4
# 1              27704         Food Service            4
# 2              27707         Food Service            2
# 3              27701         Food Service            2
# 4              27704     Residential Care            0
# 5              27703     Residential Care            0
# 6              27701             Day Care            0
# 7              27707       Swimming Pools            0
# 8              27705       Swimming Pools            0
# 9              27705       Swimming Pools            0
#
#      fields.est_group_desc  fields.seats  ...  \
# 0  Full-Service Restaurant          60.0  ...
# 1             Nursing Home         350.0  ...
# 2     Fast Food Restaurant           7.0  ...
# 3  Full-Service Restaurant         100.0  ...
# 4                     <NA>           6.0  ...
# 5                     <NA>           0.0  ...
# 6                     <NA>           NaN  ...
# 7                     <NA>           0.0  ...
# 8                     <NA>           0.0  ...
# 9                     <NA>           0.0  ...
#
#                 fields.premise_name fields.transitional_type_desc  \
# 0                  WEST 94TH ST PUB                          FOOD
# 1              BROOKDALE DURHAM IFS                          FOOD
# 2                     SMOOTHIE KING                          FOOD
# 3              HAMPTON INN & SUITES                          FOOD
# 4  BETTER LIVING CONCEPTS OF DURHAM                           N/A
# 5                   ADVENTURE HOUSE                           N/A
# 6      ANOTHER BEAUTIFUL BEGINNINGS                           N/A
# 7        BRIDGES AT SOUTHPOINT APTS                           N/A
# 8           SHEARTON INN UNIVERSITY                           N/A
# 9                   SPA HEALTH CLUB                           N/A
#
#   fields.smoking_allowed  fields.id            fields.sewage  \
# 0                     NO      56060  3 - Municipal/Community
# 1                     NO      58123  3 - Municipal/Community
# 2                     NO      70266  3 - Municipal/Community
# 3                     NO      97837  3 - Municipal/Community
# 4                    N/A      60690  3 - Municipal/Community
# 5                    N/A      60686  3 - Municipal/Community
# 6                     NO      85252  3 - Municipal/Community
# 7                    N/A      59120  3 - Municipal/Community
# 8                    N/A      59124  3 - Municipal/Community
# 9                    N/A      59263  3 - Municipal/Community
#
#        fields.premise_address1 geometry.type       geometry.coordinates  \
# 0          4711 HOPE VALLEY RD         Point  [-78.9573299, 35.9207272]
# 1       4434 BEN FRANKLIN BLVD         Point  [-78.8895483, 36.0467802]
# 2  1125 W. NC HWY 54 SUITE 806         Point  [-78.9593263, 35.9182655]
# 3            1542 N GREGSON ST         Point  [-78.9060312, 36.0183378]
# 4                909 GARCIA ST         Point  [-78.9135175, 36.0556347]
# 5            4 KIMBROUGH COURT         Point   [-78.8077969, 35.984012]
# 6             1309 ANGIER AVE.         Point  [-78.8865863, 35.9857413]
# 7         7304 CALIBRE PARK DR         Point   [-78.9602128, 35.913596]
# 8         2800 CAMPUS WALK AVE         Point   [-78.953045, 36.0111429]
# 9         3419 HILLSBOROUGH RD         Point   [-78.947422, 36.0184133]
#
#   fields.hours_of_operation fields.closing_date
# 0                      <NA>                <NA>
# 1                      <NA>                <NA>
# 2                      <NA>                <NA>
# 3                      <NA>                <NA>
# 4                      <NA>                <NA>
# 5                      <NA>                <NA>
# 6                      <NA>                <NA>
# 7                      <NA>                <NA>
# 8                      <NA>                <NA>
# 9                      <NA>                <NA>
#
# [10 rows x 28 columns]
#                datasetid                                  recordid  \
# 0  foreclosure-2006-2016  629979c85b1cc68c1d4ee8cc351050bfe3592c62
# 1  foreclosure-2006-2016  e3cce8bbc3c9b804cbd87e267a6ff121285274e0
# 2  foreclosure-2006-2016  311559ebfeffe7ebc2a8b056a034a24298da08f3
# 3  foreclosure-2006-2016  7ec0761bd385bab8af10f682115a6eb4400740b3
# 4  foreclosure-2006-2016  c81ae2921ffca8125c2de2fd3e3b1375388cd925
# 5  foreclosure-2006-2016  ae17ea44c5918fd2db5e54144cc84956c830e009
# 6  foreclosure-2006-2016  33bcfab5aa69ed55e6dc6839da2c8a5ee989e185
# 7  foreclosure-2006-2016  0322e07438201c6cf0ac4d3f3a1de3508aebcaf2
# 8  foreclosure-2006-2016  f88a039e24c4182df9c6caad4199ab23c1bfd0af
# 9  foreclosure-2006-2016  54b29375c19aff597e9843c7428b4c68399204b3
#
#             record_timestamp fields.parcel_number             fields.geocode  \
# 0  2017-03-06T12:41:48-05:00               110138  [36.0013755, -78.8922549]
# 1  2017-03-06T12:41:48-05:00               110535    [35.995797, -78.895396]
# 2  2017-03-06T12:41:48-05:00               110536   [35.995413, -78.8950321]
# 3  2017-03-06T12:41:48-05:00               111324  [35.9957683, -78.8873774]
# 4  2017-03-06T12:41:48-05:00               111399    [35.993026, -78.888343]
# 5  2017-03-06T12:41:48-05:00               111426     [35.99217, -78.888092]
# 6  2017-03-06T12:41:48-05:00               112166   [35.9865799, -78.886681]
# 7  2017-03-06T12:41:48-05:00               112278  [35.9815968, -78.8806365]
# 8  2017-03-06T12:41:48-05:00               112934    [35.992438, -78.874621]
# 9  2017-03-06T12:41:48-05:00               114277    [35.985903, -78.869642]
#
#          fields.address fields.year geometry.type       geometry.coordinates
# 0  217 E CORPORATION ST        2006         Point  [-78.8922549, 36.0013755]
# 1        401 N QUEEN ST        2006         Point    [-78.895396, 35.995797]
# 2        403 N QUEEN ST        2006         Point   [-78.8950321, 35.995413]
# 3        918 GILBERT ST        2006         Point  [-78.8873774, 35.9957683]
# 4        721 LIBERTY ST        2006         Point    [-78.888343, 35.993026]
# 5        729 HOPKINS ST        2006         Point     [-78.888092, 35.99217]
# 6        1302 E MAIN ST        2006         Point   [-78.886681, 35.9865799]
# 7           402 CLAY ST        2006         Point  [-78.8806365, 35.9815968]
# 8       1516 LATHROP ST        2006         Point    [-78.874621, 35.992438]
# 9        2604 E MAIN ST        2006         Point    [-78.869642, 35.985903]

# %%
res_filtered = restaurants[(restaurants['fields.status'] == 'ACTIVE') & (restaurants['fields.rpt_area_desc'] == 'Food Service')]
print(res_filtered.head(10))
# Out:
#            datasetid                                  recordid  \
# 0   restaurants-data  1644654b953d1802c3c941211f61be1f727b2951
# 1   restaurants-data  93573dbf8c9e799d82c459e47de0f40a2faa47bb
# 2   restaurants-data  0d274200c7cef50d05dd633bc5da896a69e1bb99
# 3   restaurants-data  cf3e0b175a6ebad2a9aa8edb4b3985c6391ed31d
# 10  restaurants-data  6c31810f57775266e2d88f58a38ab21bffc8e267
# 11  restaurants-data  3920e7cdf00cbfb2c2e1d40296ac0d1151939fb0
# 12  restaurants-data  4a803ed1eb23942b7360fbac36efa80d3f599ef6
# 13  restaurants-data  f89ee52d319aab04c91b097353ac853a38c85043
# 14  restaurants-data  eaf7b61888aad93d1a132e628998258615d8aff7
# 19  restaurants-data  290c641ae1be2b74ddb841e7ccded4f5b3144149
#
#              record_timestamp fields.status         fields.geolocation  \
# 0   2017-07-13T09:15:31-04:00        ACTIVE  [35.9207272, -78.9573299]
# 1   2017-07-13T09:15:31-04:00        ACTIVE  [36.0467802, -78.8895483]
# 2   2017-07-13T09:15:31-04:00        ACTIVE  [35.9182655, -78.9593263]
# 3   2017-07-13T09:15:31-04:00        ACTIVE  [36.0183378, -78.9060312]
# 10  2017-07-13T09:15:31-04:00        ACTIVE  [35.9495321, -78.9211694]
# 11  2017-07-13T09:15:31-04:00        ACTIVE   [35.9852771, -78.898944]
# 12  2017-07-13T09:15:31-04:00        ACTIVE  [36.0586094, -78.9279599]
# 13  2017-07-13T09:15:31-04:00        ACTIVE  [36.0094173, -78.9218729]
# 14  2017-07-13T09:15:31-04:00        ACTIVE   [36.018111, -78.9102149]
# 19  2017-07-13T09:15:31-04:00        ACTIVE   [36.001517, -78.9391734]
#
#    fields.premise_zip fields.rpt_area_desc  fields.risk  \
# 0               27707         Food Service            4
# 1               27704         Food Service            4
# 2               27707         Food Service            2
# 3               27701         Food Service            2
# 10              27707         Food Service            3
# 11              27701         Food Service            3
# 12              27705         Food Service            2
# 13              27705         Food Service            4
# 14              27701         Food Service            2
# 19              27708         Food Service            4
#
#           fields.est_group_desc  fields.seats  ...  \
# 0       Full-Service Restaurant          60.0  ...
# 1                  Nursing Home         350.0  ...
# 2          Fast Food Restaurant           7.0  ...
# 3       Full-Service Restaurant         100.0  ...
# 10  Meat and Poultry Department           0.0  ...
# 11                         <NA>           0.0  ...
# 12         Fast Food Restaurant           0.0  ...
# 13         Fast Food Restaurant          36.0  ...
# 14         Fast Food Restaurant           0.0  ...
# 19         Fast Food Restaurant         100.0  ...
#
#                         fields.premise_name fields.transitional_type_desc  \
# 0                          WEST 94TH ST PUB                          FOOD
# 1                      BROOKDALE DURHAM IFS                          FOOD
# 2                             SMOOTHIE KING                          FOOD
# 3                      HAMPTON INN & SUITES                          FOOD
# 10                 KROGER R 381 MEAT MARKET                          FOOD
# 11  LEONE INTERNATIONAL GROCERY/MEAT MARKET                          FOOD
# 12                       PIZZA HUT DELIVERY                          FOOD
# 13                            CHUBBYS TACOS                          FOOD
# 14                                   SUBWAY                          FOOD
# 19     DUKE UNIVERSITY WEST UNION FARMSTEAD                          FOOD
#
#    fields.smoking_allowed  fields.id            fields.sewage  \
# 0                      NO      56060  3 - Municipal/Community
# 1                      NO      58123  3 - Municipal/Community
# 2                      NO      70266  3 - Municipal/Community
# 3                      NO      97837  3 - Municipal/Community
# 10                    N/A      58349  3 - Municipal/Community
# 11                     NO      58342  3 - Municipal/Community
# 12                    N/A      57278  3 - Municipal/Community
# 13                    N/A      57190  3 - Municipal/Community
# 14                     NO      57585  3 - Municipal/Community
# 19                    N/A     178137  3 - Municipal/Community
#
#         fields.premise_address1 geometry.type       geometry.coordinates  \
# 0           4711 HOPE VALLEY RD         Point  [-78.9573299, 35.9207272]
# 1        4434 BEN FRANKLIN BLVD         Point  [-78.8895483, 36.0467802]
# 2   1125 W. NC HWY 54 SUITE 806         Point  [-78.9593263, 35.9182655]
# 3             1542 N GREGSON ST         Point  [-78.9060312, 36.0183378]
# 10            3825 S ROXBORO ST         Point  [-78.9211694, 35.9495321]
# 11          810 FAYETTEVILLE ST         Point   [-78.898944, 35.9852771]
# 12              3808 GUESS ROAD         Point  [-78.9279599, 36.0586094]
# 13             748 NINTH STREET         Point  [-78.9218729, 36.0094173]
# 14                  1058 W CLUB         Point   [-78.9102149, 36.018111]
# 19             406 CHAPEL DRIVE         Point   [-78.9391734, 36.001517]
#
#    fields.hours_of_operation fields.closing_date
# 0                       <NA>                <NA>
# 1                       <NA>                <NA>
# 2                       <NA>                <NA>
# 3                       <NA>                <NA>
# 10                      <NA>                <NA>
# 11                      <NA>                <NA>
# 12                      <NA>                <NA>
# 13                      <NA>                <NA>
# 14                      <NA>                <NA>
# 19                      <NA>                <NA>
#
# [10 rows x 28 columns]

# %%
foreclosure = foreclosure.compute()
foreclosure = pd.DataFrame(foreclosure['geometry.coordinates'])
print(foreclosure.head(10))
# Out:
#         geometry.coordinates
# 0  [-78.8922549, 36.0013755]
# 1    [-78.895396, 35.995797]
# 2   [-78.8950321, 35.995413]
# 3  [-78.8873774, 35.9957683]
# 4    [-78.888343, 35.993026]
# 5     [-78.888092, 35.99217]
# 6   [-78.886681, 35.9865799]
# 7  [-78.8806365, 35.9815968]
# 8    [-78.874621, 35.992438]
# 9    [-78.869642, 35.985903]

# %%
def foreclosure_count(row, foreclosures):
    count = 0
    try:
        float_list = ast.literal_eval(row['geometry.coordinates'])
        r_lat, r_lon = float_list[0], float_list[1]
    except:
        count = 0 
        return count
        
    for index, row in foreclosures.iterrows():
        # Access geocode data for each foreclosure entry.
        coords = row['geometry.coordinates']
        try:
            float_list = ast.literal_eval(coords)
            f_lat, f_lon = float_list[0], float_list[1]
        except:
            continue
        distance = haversine((r_lat, r_lon), (f_lat, f_lon), unit=Unit.MILES)    
        if distance <= 1:  # 1 mile in km
            count += 1
    return count

res_filtered['count_closed'] = res_filtered.apply(lambda row: foreclosure_count(row, foreclosure), axis=1)
# Out:
# /opt/conda/envs/dask/lib/python3.10/site-packages/dask_expr/_collection.py:3061: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'int64'))
#
#   warnings.warn(meta_warning(meta))

# %%
# Sort the DataFrame by 'foreclosure_count' in descending order.
sorted_restaurants_df = res_filtered.sort_values(by='count_closed', ascending=False)

# Print the top 10 results from the sorted DataFrame.
print(sorted_restaurants_df[['fields.premise_name', 'count_closed']].head(10))
# Out:
#           fields.premise_name  count_closed
# 316    LOS PRIMOS SUPERMARKET           764
# 988   BURTON SCHOOL LUNCHROOM           760
# 1118         TATER BREAD CAFE           757
# 1443   AMERICAN LEGION POST 7           752
# 1767   SAVE-A-LOT MEAT MARKET           742
# 1164          THE COTTON ROOM           742
# 205     QUICK LUNCH RICO TACO           735
# 1002        TOWN DELI GROCERY           734
# 280              JC'S KITCHEN           721
# 1777  GLOBAL SCHOLARS ACADEMY           719
